# %%
import re
import json

import requests

# %%
with open('./temp/re_test.html', 'r') as f:
    text = f.read()

# %%
match = re.search(r'({"@context"(?!</script>).*)\s*</script>', text)[1]
match
# Out:
# '{"@context":"http:\\/\\/schema.org","@type":"ImageObject","caption":"Nude with neon pink \\u26a1\\u26a1\\u26a1\\n#nudenails #neonpinknails\\ud83d\\udc85\\ud83c\\udf80 #epicpics #longnails #almondnails #almondshape #donebyme #XaneczkaaNails #inlove\\ud83d\\udc95 #lightnings","representativeOfPage":"http:\\/\\/schema.org\\/True","uploadDate":"2019-05-08T21:42:04","author":{"@type":"Person","alternateName":"@x_ankaa","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\\/\\/www.instagram.com\\/x_ankaa\\/"}},"commentCount":"0","interactionStatistic":{"@type":"InteractionCounter","interactionType":{"@type":"LikeAction"},"userInteractionCount":"3"},"mainEntityofPage":{"@type":"ItemPage","@id":"https:\\/\\/www.instagram.com\\/p\\/BxN4641BH0x\\/"},"description":"3 Likes, 0 Comments - Xaneczkaa \\ud83d\\udc51 (@x_ankaa) on Instagram: \\u201cNude with neon pink \\u26a1\\u26a1\\u26a1 #nudenails #neonpinknails\\ud83d\\udc85\\ud83c\\udf80 #epicpics #longnails #almondnails #almondshape\\u2026\
# ...

# %%
json.loads(match)
# Out:
# {'@context': 'http://schema.org',
#  '@type': 'ImageObject',
#  'caption': 'Nude with neon pink ⚡⚡⚡\n#nudenails #neonpinknails💅🎀 #epicpics #longnails #almondnails #almondshape #donebyme #XaneczkaaNails #inlove💕 #lightnings',
#  'representativeOfPage': 'http://schema.org/True',
#  'uploadDate': '2019-05-08T21:42:04',
#  'author': {'@type': 'Person',
#   'alternateName': '@x_ankaa',
#   'mainEntityofPage': {'@type': 'ProfilePage',
#    '@id': 'https://www.instagram.com/x_ankaa/'}},
#  'commentCount': '0',
#  'interactionStatistic': {'@type': 'InteractionCounter',
#   'interactionType': {'@type': 'LikeAction'},
#   'userInteractionCount': '3'},
#  'mainEntityofPage': {'@type': 'ItemPage',
#   '@id': 'https://www.instagram.com/p/BxN4641BH0x/'},
#  'description': '3 Likes, 0 Comments - Xaneczkaa 👑 (@x_ankaa) on Instagram: “Nude with neon pink ⚡⚡⚡ #nudenails #neonpinknails💅🎀 #epicpics #longnails #almondnails #almondshape…”',
# ...

# %%
j = {"@context":"http:\/\/schema.org","@type":"VideoObject","caption":"\u0412 \u044d\u0442\u043e\u043c \u0433\u043e\u0434\u0443 \u043f\u043e\u0433\u043e\u0434\u0430 \u0447\u0443\u0434\u0438\u0442 \ud83e\udd37\ud83c\udffc\u200d\u2640\ufe0f\n\u0410\u043f\u0440\u0435\u043b\u044c\u0441\u043a\u0430\u044f \u043c\u043e\u043b\u043d\u0438\u044f \u043f\u043e\u043f\u0430\u043b\u0430 \u0432 \u0448\u043f\u0438\u043b\u044c \u0411\u0443\u0440\u0436 \u0425\u0430\u043b\u0438\u0444\u0430\ud83d\udda4","uploadDate":"2019-04-14T04:48:41","author":{"@type":"Person","alternateName":"@dubai.tourguide","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/dubai.tourguide\/"}},"comment":[{"@type":"Comment","text":"#Dubai #dubaiguide #dubaitour #uae #mydubai #sharjah #\u044d\u043a\u0441\u043a\u0443\u0440\u0441\u0438\u0438 #\u044d\u043a\u0441\u043a\u0443\u0440\u0441\u0438\u0438\u0434\u0443\u0431\u0430\u0439 #\u044d\u043a\u0441\u043a\u0443\u0440\u0441\u0438\u0438\u043e\u0430\u044d #\u0442\u0443\u0440\u0434\u0443\u0431\u0430\u0439 #\u0442\u0443\u0440\u043e\u0430\u044d #\u0448\u0430\u0440\u0434\u0436\u0430 #\u0433\u0438\u0434\u0432\u0434\u0443\u0431\u0430\u0435 #\u0433\u0438\u0434\u0432\u043e\u0430\u044d #\u0447\u0430\u0441\u0442\u043d\u044b\u0439\u0433\u0438\u0434 #\u0447\u0430\u0441\u0442\u043d\u044b\u0439\u0433\u0438\u0434\u043e\u0430\u044d #\u0447\u0430\u0441\u0442\u043d\u044b\u0439\u0433\u0438\u0434\u0434\u0443\u0431\u0430\u0439 #\u0433\u0438\u0434\u0434\u0443\u0431\u0430\u0439 #\u0431\u0443\u0440\u0436\u0445\u0430\u043b\u0438\u0444\u0430 #burjkhalifa #slowmotion #lightnings","author":{"@type":"Person","alternateName":"@dubai.tourguide","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/dubai.tourguide\/"}}},{"@type":"Comment","text":"\u0416\u0443\u0442\u044c","author":{"@type":"Person","alternateName":"@olegparadox_","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/olegparadox_\/"}}},{"@type":"Comment","text":"@olegparadox_ \u0430\u0433\u0430, \u0436\u0443\u0442\u043a\u043e\u0432\u0430\u0442\u043e \u0432\u044b\u0433\u043b\u044f\u0434\u0438\u0442 \ud83d\ude05","author":{"@type":"Person","alternateName":"@dubai.tourguide","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/dubai.tourguide\/"}}},{"@type":"Comment","text":"\u041a\u0440\u0430\u0441\u0438\u0432\u043e \u0442\u043e \u043a\u0430\u043a!","author":{"@type":"Person","alternateName":"@yazaitsev","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/yazaitsev\/"}}},{"@type":"Comment","text":"@yazaitsev \u0437\u0430\u0432\u043e\u0440\u0430\u0436\u0438\u0432\u0430\u0435\u0442!","author":{"@type":"Person","alternateName":"@dubai.tourguide","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/dubai.tourguide\/"}}},{"@type":"Comment","text":"\u041a\u0440\u0443\u0442\u043e ... \u0438 \u0437\u0430\u0432\u043e\u0440\u0430\u0436\u0438\u0432\u0430\u044e\u0449\u0435","author":{"@type":"Person","alternateName":"@amico8888","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/amico8888\/"}}},{"@type":"Comment","text":"\u041c\u0435\u0441\u0442\u043d\u044b\u0435 \u0433\u043e\u0432\u043e\u0440\u044f\u0442, \u0447\u0442\u043e \u044d\u0442\u043e \u0432\u0441\u0435 \u043f\u0440\u0438 \u043f\u043e\u043c\u043e\u0449\u0438 \u0441\u0430\u043c\u043e\u043b\u0435\u0442\u043e\u0432 \u0434\u0435\u043b\u0430\u044e\u0442 \u0441\u043f\u0435\u0446\u0438\u0430\u043b\u044c\u043d\u043e \ud83e\udd37\ud83c\udffc\u200d\u2640\ufe0f","author":{"@type":"Person","alternateName":"@dros_andros","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/dros_andros\/"}}},{"@type":"Comment","text":"\u0414\u0430\u0441 \u0438\u0441\u0442 \u0444\u0430\u043d\u0442\u0430\u0441\u0442\u0438\u0448 !","author":{"@type":"Person","alternateName":"@lenaschipaceva","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/lenaschipaceva\/"}}},{"@type":"Comment","text":"\u041a\u0443\u0434\u0430-\u0442\u043e \u0436 \u043d\u0430\u0434\u043e \u043c\u043e\u043b\u043d\u0438\u0438 \u043f\u043e\u043f\u0430\u0441\u0442\u044c.\u0414\u043e\u0436\u0434\u044c \u0442\u043e\u0436\u0435 \u0431\u044b\u043b?","author":{"@type":"Person","alternateName":"@medan_25","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/medan_25\/"}}},{"@type":"Comment","text":"@medan_25 \u043a\u043e\u043d\u0435\u0447\u043d\u043e:)","author":{"@type":"Person","alternateName":"@dubai.tourguide","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/dubai.tourguide\/"}}},{"@type":"Comment","text":"@dros_andros \u043d\u0435 \u043c\u043e\u043b\u043d\u0438\u0438. \u0418\u043d\u043e\u0433\u0434\u0430 \u043c\u0435\u0441\u0442\u043d\u044b\u0435 \u0432\u043b\u0430\u0441\u0442\u0438 \u0441\u043f\u0435\u0446\u0438\u0430\u043b\u044c\u043d\u043e \u0432\u044b\u0437\u044b\u0432\u0430\u044e\u0442 \u0434\u043e\u0436\u0434\u0438, \u043d\u043e \u044d\u0442\u043e \u043d\u0435 \u0442\u043e\u0442 \u0441\u043b\u0443\u0447\u0430\u0439","author":{"@type":"Person","alternateName":"@dubai.tourguide","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/dubai.tourguide\/"}}},{"@type":"Comment","text":"@amico8888 \u0434\u0430! \u041e\u0447\u0435\u043d\u044c \u043a\u0440\u0443\u0442\u043e \u043f\u043e\u0439\u043c\u0430\u043b\u0438 \u043c\u043e\u043c\u0435\u043d\u0442!","author":{"@type":"Person","alternateName":"@dubai.tourguide","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/dubai.tourguide\/"}}},{"@type":"Comment","text":"@dubai.tourguide  \u0412\u0438\u0434\u0435\u043b\u0430 \u044d\u0442\u043e\u0442 \u043c\u043e\u043c\u0435\u043d\u0442  \u0435\u0449\u0451 .. \u043f\u0440\u043e\u0441\u0442\u043e  \u043e\u0444\u0438\u0433\u0435\u043d\u043d\u043e","author":{"@type":"Person","alternateName":"@amico8888","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/amico8888\/"}}},{"@type":"Comment","text":"\ud83e\udd24\ud83d\ude32\ud83d\ude2f","author":{"@type":"Person","alternateName":"@evictoria1965","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/evictoria1965\/"}}},{"@type":"Comment","text":"@aalmagicoo","author":{"@type":"Person","alternateName":"@arch.m.ayyad","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/arch.m.ayyad\/"}}},{"@type":"Comment","text":"\u0421\u0442\u0440\u0430\u0448\u043d\u043e \ud83d\ude44","author":{"@type":"Person","alternateName":"@evgenia_010_","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/evgenia_010_\/"}}},{"@type":"Comment","text":"\ud83e\uddd0","author":{"@type":"Person","alternateName":"@orazlivaeva","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/orazlivaeva\/"}}},{"@type":"Comment","text":"@dubai.tourguide \u043e\u0431\u043e\u0436\u0430\u044e \u0433\u0440\u043e\u0437\u0443 \u0438 \u043c\u043e\u043b\u043d\u0438\u0438!\ud83d\udc93","author":{"@type":"Person","alternateName":"@yazaitsev","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/yazaitsev\/"}}},{"@type":"Comment","text":"\u041d\u0430\u0434\u0435\u044e\u0441\u044c \ud83d\ude2e,\u0447\u0442\u043e \u043d\u0438\u043a\u0442\u043e \u043d\u0435 \u043f\u043e\u0441\u0442\u0440\u0430\u0434\u0430\u043b","author":{"@type":"Person","alternateName":"@kravchuk4275","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/kravchuk4275\/"}}},{"@type":"Comment","text":"@kravchuk4275 \u043a\u043e\u043d\u0435\u0447\u043d\u043e, \u043d\u0435\u0442! \u041c\u043e\u043b\u043d\u0438\u044f \u0431\u044c\u0435\u0442 \u0432 \u0433\u0440\u043e\u043c\u043e\u043e\u0442\u0432\u043e\u0434:)","author":{"@type":"Person","alternateName":"@dubai.tourguide","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/dubai.tourguide\/"}}},{"@type":"Comment","text":"@evgenia_010_ \u043d\u043e \u043a\u0440\u0430\u0441\u0438\u0432\u043e \ud83d\ude0d","author":{"@type":"Person","alternateName":"@dubai.tourguide","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/dubai.tourguide\/"}}},{"@type":"Comment","text":"@dubai.tourguide \u043e\u043e\u043e\u0447\u0435\u043d\u044c \ud83d\udc4f","author":{"@type":"Person","alternateName":"@evgenia_010_","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/evgenia_010_\/"}}},{"@type":"Comment","text":"@x_queen_mari_x  gestern in Dubai \ud83d\ude31","author":{"@type":"Person","alternateName":"@__francis2501__","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/__francis2501__\/"}}},{"@type":"Comment","text":"@saad.ali.amjad","author":{"@type":"Person","alternateName":"@aishanayyer90","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/aishanayyer90\/"}}},{"@type":"Comment","text":"\u041d\u0438\u043a\u043e\u043b\u0430 \u0422\u0435\u0441\u043b\u0430 \u0432\u0435\u0440\u043d\u0443\u043b\u0441\u044f.","author":{"@type":"Person","alternateName":"@kupimtut.by_baranovichi","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/kupimtut.by_baranovichi\/"}}},{"@type":"Comment","text":"\u0423\u0436\u0430\u0441\ud83d\ude31\u043f\u0440\u043e\u043d\u0435\u0441\u043b\u043e \u043e\u0442 \u0432\u043e\u0437\u0433\u043e\u0440\u0430\u043d\u0438\u044f\ud83d\ude4f","author":{"@type":"Person","alternateName":"@ol_za26","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/ol_za26\/"}}},{"@type":"Comment","text":"@thaiscandv @ivancmiranda @romulomatildes @marianastoffella, pensa.... \u26a1\ud83d\ude1f","author":{"@type":"Person","alternateName":"@nathalia.alvesmatildes","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/nathalia.alvesmatildes\/"}}},{"@type":"Comment","text":"@nathalia.alvesmatildes caraca... pelos poderes de Glaiscow...","author":{"@type":"Person","alternateName":"@ivancmiranda","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/ivancmiranda\/"}}},{"@type":"Comment","text":"\u2705","author":{"@type":"Person","alternateName":"@shenty97120","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/shenty97120\/"}}},{"@type":"Comment","text":"\u2705","author":{"@type":"Person","alternateName":"@sonia_kaya974","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/sonia_kaya974\/"}}},{"@type":"Comment","text":"@nathalia.alvesmatildes \ud83d\ude31","author":{"@type":"Person","alternateName":"@marianastoffella","mainEntityofPage":{"@type":"ProfilePage","@id":"https:\/\/www.instagram.com\/marianastoffella\/"}}}],"commentCount":"31","contentLocation":{"@type":"Place","name":"Burj Khalifa","mainEntityofPage":{"@type":"CollectionPage","@id":"https:\/\/www.instagram.com\/explore\/locations\/217595490\/burj-khalifa\/"},"address":{"@type":"PostalAddress","streetAddress":"1, Mohammed Bin Rashid Boulevard  ","postalCode":"P.O.Box: 888888","addressLocality":"Dubai, United Arab Emirates","addressCountry":{"@type":"Country","name":"AE"}}},"interactionStatistic":{"@type":"InteractionCounter","interactionType":{"@type":"WatchAction"},"userInteractionCount":"5542"},"mainEntityofPage":{"@type":"ItemPage","@id":"https:\/\/www.instagram.com\/p\/BwORsEhAyFm\/"},"description":"756 Likes, 31 Comments - \u0414\u0423\u0411\u0410\u0419\/\u041e\u0410\u042d\ud83c\udde6\ud83c\uddea (@dubai.tourguide) on Instagram: \u201c\u0412 \u044d\u0442\u043e\u043c \u0433\u043e\u0434\u0443 \u043f\u043e\u0433\u043e\u0434\u0430 \u0447\u0443\u0434\u0438\u0442 \ud83e\udd37\ud83c\udffc\u200d\u2640\ufe0f\n\u0410\u043f\u0440\u0435\u043b\u044c\u0441\u043a\u0430\u044f \u043c\u043e\u043b\u043d\u0438\u044f \u043f\u043e\u043f\u0430\u043b\u0430 \u0432 \u0448\u043f\u0438\u043b\u044c \u0411\u0443\u0440\u0436 \u0425\u0430\u043b\u0438\u0444\u0430\ud83d\udda4\u201d","name":"\u0414\u0423\u0411\u0410\u0419\/\u041e\u0410\u042d\ud83c\udde6\ud83c\uddea on Instagram: \u201c\u0412 \u044d\u0442\u043e\u043c \u0433\u043e\u0434\u0443 \u043f\u043e\u0433\u043e\u0434\u0430 \u0447\u0443\u0434\u0438\u0442 \ud83e\udd37\ud83c\udffc\u200d\u2640\ufe0f\n\u0410\u043f\u0440\u0435\u043b\u044c\u0441\u043a\u0430\u044f \u043c\u043e\u043b\u043d\u0438\u044f \u043f\u043e\u043f\u0430\u043b\u0430 \u0432 \u0448\u043f\u0438\u043b\u044c \u0411\u0443\u0440\u0436 \u0425\u0430\u043b\u0438\u0444\u0430\ud83d\udda4\u201d","thumbnailUrl":"https:\/\/scontent-arn2-2.cdninstagram.com\/vp\/e9d9866cf90de6ab1463d8d3403c485b\/5CD56C43\/t51.2885-15\/e35\/c0.80.640.640a\/55908277_139142877209080_4832463404675904037_n.jpg?_nc_ht=scontent-arn2-2.cdninstagram.com"}

# %%
url = j['contentLocation']['mainEntityofPage']['@id'].replace("\\", '')
url
# Out:
# 'https://www.instagram.com/explore/locations/217595490/burj-khalifa/'

# %%
response = requests.get(url)

# %%
with open('./temp/mainEntity.html', 'w') as f:
    f.write(response.text)

# %%
match = re.search(r'_sharedData\s*=\s*((?!</script>).*);</script>', response.text)[1]
json.loads(match)['entry_data']['LocationsPage'][0]['graphql']['location']
# Out:
# {'id': '217595490',
#  'name': 'Burj Khalifa',
#  'has_public_page': True,
#  'lat': 25.197587,
#  'lng': 55.2741737,
#  'slug': 'burj-khalifa',
#  'blurb': 'Welcome to the official page of Burj Khalifa, the world’s tallest building   ‘A Living Wonder’ by Emaar.',
#  'website': 'http://www.burjkhalifa.ae',
#  'phone': '+97148888888',
#  'primary_alias_on_fb': 'BurjKhalifa',
#  'address_json': '{"street_address": "1, Mohammed Bin Rashid Boulevard  ", "zip_code": "P.O.Box: 888888", "city_name": "Dubai, United Arab Emirates", "region_name": "", "country_code": "AE", "exact_city_match": false, "exact_region_match": false, "exact_country_match": false}',
#  'profile_pic_url': 'https://scontent-arn2-2.cdninstagram.com/vp/3aeee11e5bb2d05f36863f31eda06574/5D5FE2F8/t51.2885-15/e35/c0.180.1440.1440/s150x150/59168555_141452566985866_1107348491750536181_n.jpg?_nc_ht=scontent-arn2-2.cdninstagram.com',
#  'edge_location_to_media': {'count': 1591180,
# ...
